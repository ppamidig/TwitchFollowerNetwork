# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import networkx as nx
import requests
import datetime
import time

# %%
G = nx.Graph()
G.add_edge(1245,1246)
labels = {}
labels[1245] = 'abcd'
labels[1246] = 'asd'
nx.draw_networkx(G, labels = labels)
plt.show()
